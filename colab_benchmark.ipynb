# %% [markdown]
# # H3 Activation Steering Benchmark
# This notebook clones the H3 repository, sets up the environment, downloads the MSCOCO val2014 dataset, and runs the evaluation benchmark to compare output-level suppression vs context-level activation steering.

# %%
# !git clone https://github.com/dzungnguyen21/h3.git
# %cd h3
# !pip install transformers accelerate pycocotools nltk scikit-learn pillow

# %% [markdown]
# ## Setup Data and Models
# The following command downloads MSCOCO annotations and 500 images if they are not already downloaded.

# %%
# !python load_data.py

# %% [markdown]
# ## Run Benchmark
# This script will sequentially load the models, generate baseline annotations (Pass 1), run the probe to extract the H3 direction, train the calibration classifier, and finally benchmark Pass 1 (no intervention), Pass 2 (output suppression), and Pass 3 (context steering).

# %%
# !python run_benchmark.py
